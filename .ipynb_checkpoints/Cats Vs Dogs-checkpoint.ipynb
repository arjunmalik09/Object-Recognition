# %%
import skimage
import numpy as np
import cv2

from sklearn import svm
from sklearn.externals import joblib
from functions import show, put_labels

from constants import *
from skimage.feature import hog

# %%
def drop_features(lt,j=2):
    lt = [lt[i] for i in range(len(lt)) if i%j==0]
    return lt

def filter_features(fd):
    return [f for f in fd if len(f)==2048]

def filter_region(region):
    width = region[2] - region[0]
    height = region[3] - region[1]
    # Incorrect region
    if width==0 or height==0:
        print "Incorrect region",region
        return True
    # distorted rects
#     if width / height > 4 or height / width > 4:
#         return True
    return False

# %%
class_positives = np.load('cat_vs_dogs_positives.npy')

#get dicts from numpy array
class_positives = class_positives[()]

# %%
dog = class_positives['dog']
cat = class_positives['cat']
print 'before filtering',len(dog),len(cat)
dog = filter_features(dog)
cat = filter_features(cat)
print 'after filtering',len(dog),len(cat)
# Out:
# before filtering 538 389
# after filtering 538 389

# %%
#extract train data
X = []
X.extend(dog)
y = [1]*len(dog)
X.extend(cat)
y.extend([0]*len(cat))   
X = np.array(X)
y = np.array(y)

# %%
def extract(image,box=None):
    """Returns hog feature descriptor for an image.
    """
    #print 'initial',image.shape
    #print len(image)
    if box is not None:
        image = image[box[0]:box[2],box[1]:box[3]]
    
    #resize image
    #print image.shape
    #print len(image)
    image = resize(image)
    #print image.shape
    #image = color.rgb2gray(img)
    fd = hog(image, orientations=8, pixels_per_cell=(image.shape[1]/16, image.shape[0]/16),
                    cells_per_block=(1, 1), visualise=False, transform_sqrt=True)
    #print len(fd)
    return fd

def resize(image):
    if image.shape[1]/image.shape[0] >= 2:
        image = cv2.resize(image,(128,64))
    elif float(image.shape[1])/image.shape[0] <= 0.5:
        image = cv2.resize(image,(64,128))
    else:
        image = cv2.resize(image,(128,128))
    return image

# %%
#load test data
test_ground_truth = np.load('test_ground_truth.npy')
test_ground_truth[0][1]
# Out:
# [{'dog': (48, 240, 195, 371)}, {'person': (8, 12, 352, 498)}]

# %%
#extract test data
d = {'cat':0,'dog':1}
Xtest,ytest = list(),list()
imgs,i_boxes = list(),list()
for i in range(len(test_ground_truth)):
    boxes = list()
    for dt in test_ground_truth[i][1]:
        if 'dog' in dt or 'cat' in dt:
            if filter_region(dt.values()[0]):
                print dt
            else:
                boxes.append(dt)
    if len(boxes)!=0:
        name = test_ground_truth[i][0]
        imgs.append(name)
        i_boxes.append(boxes)
        img = cv2.imread(folder_test + '/' + name,0)
        #print name,boxes
        for box in boxes:
            #print box.values()[0]
            p_box = box.values()[0]
            p_box = p_box[1::-1] + p_box[3:1:-1] 
            Xtest.append(extract(img,p_box))
            ytest.append(d[box.keys()[0]])

# %%
len(ytest)
# Out:
# 387

# %%
print 'Training for cat vs dogs'
print 'Feature Vectors:',len(X)
from sklearn.grid_search import GridSearchCV
print("Fitting the classifier to the training set")
param_grid = {'C': [0.01, 0.1, 1, 10, 100],'gamma':[0.01, 0.1, 1, 10, 100], 'kernel': ['rbf', 'linear']}
clf = GridSearchCV(svm.SVC(probability=True,class_weight='balanced'), param_grid,n_jobs=3)
clf = clf.fit(X, y)
print("Best estimator found by grid search:")
print(clf.best_estimator_)

# clf = svm.SVC(gamma=0.01, C=100,probability=True)
# clf.fit(X, y)
# Out:
# Training for cat vs dogs
# Feature Vectors: 927
# Fitting the classifier to the training set
# Best estimator found by grid search:
# SVC(C=1, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# i_boxes = [[(94,1,442,374)],[(126,51,330,308)],[(48,240,195,371),(8,12,352,498)],[(31,30,358,279)],[(63,18,374,500)]]
# imgs = [cv2.imread('Cat vs Dog Data/000442.jpg',0),cv2.imread('Cat vs Dog Data/000011.jpg',0),
#         cv2.imread('000001.jpg',0),cv2.imread('Cat vs Dog Data/000018.jpg',0),
#         cv2.imread('Cat vs Dog Data/000028.jpg',0)]
pred = clf.predict(Xtest)
from sklearn import metrics
print("Confusion matrix:\n%s" %metrics.confusion_matrix(ytest,pred))
print("Accuracy: %0.4f" % metrics.accuracy_score(ytest,pred))
print "{0}".format(metrics.classification_report(ytest,pred))
# Out:
# Confusion matrix:
# [[ 89  61]
#  [ 66 171]]
# Accuracy: 0.6718
#              precision    recall  f1-score   support
#
#           0       0.57      0.59      0.58       150
#           1       0.74      0.72      0.73       237
#
# avg / total       0.67      0.67      0.67       387

# %%
from sklearn.externals import joblib 
joblib.dump(clf, 'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl')
# Out:
# ['Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_01.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_02.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_03.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_04.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_05.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_06.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_07.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_08.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_09.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_10.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_11.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_12.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_13.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_14.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_15.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_16.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_17.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_18.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_19.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_20.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_21.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_22.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_23.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_24.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_25.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_26.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_27.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_28.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_29.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_30.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_31.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_32.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_33.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_34.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_35.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_36.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_37.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_38.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_39.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_40.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_41.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_42.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_43.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_44.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_45.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_46.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_47.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_48.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_49.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_50.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_51.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_52.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_53.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_54.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_55.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_56.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_57.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_58.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_59.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_60.npy',
#  'Cats Vs Dogs Classifier/cat_pos_vs_dog_pos.pkl_61.npy']

# %%
def find_class(clf,imgs,i_boxes):
    # if boxes is None:
    from extract import extract
    d = {0:'cat',1:'dog'}
    for img,boxes in zip(imgs,i_boxes):
        labels = []
        show(img)
        for box in boxes:
            print box
            input = extract(img,box)
#             print clf.predict_proba([input])
            labels.append(d[clf.predict([input])[0]])
        print labels
        put_labels(img,boxes,labels)
# Out:
# 500

# %%
test_regions = np.load('test_regns.npy')

# %%
def filter_detections(detections):
    sorted(detections)
    print detections

# %%
from os import path
for dt in test_regions:
    name = path.join(folder_test,dt.keys()[0])
    img = cv2.imread(name,0)
    regions = dt.values()[0]
    probs,labels = list(),list()
    for regn in regions:
        fd = extract(img,regn)
        probs.append(max(clf.predict_proba([fd])[0]))
        labels.append(clf.predict([fd]))
    detections = zip(probs,labels,regions)
    detections = filter_detections(detections)
# Out:
# [(0.51530601171044499, array([0]), (149, 163, 319, 352)), (0.90520669829755529, array([1]), (106, 141, 175, 200)), (0.51318746879163923, array([0]), (145, 217, 279, 281)), (0.62842833811988152, array([0]), (0, 145, 23, 168)), (0.59018478678328534, array([0]), (0, 32, 15, 59)), (0.72805268766235365, array([1]), (112, 0, 172, 37)), (0.64948497863126242, array([0]), (0, 111, 46, 137)), (0.53398186768402278, array([0]), (10, 191, 36, 266)), (0.63764412381709579, array([1]), (5, 143, 80, 292)), (0.58129434331259799, array([1]), (111, 22, 129, 49)), (0.5953603429911497, array([0]), (460, 147, 494, 225)), (0.78301041744634647, array([0]), (145, 147, 223, 173)), (0.63207104565240146, array([0]), (0, 19, 69, 62)), (0.57621220869732104, array([1]), (0, 96, 11, 117)), (0.63207104565240146, array([0]), (0, 19, 69, 62)), (0.6706549508989158, array([0]), (225, 115, 268, 147)), (0.70428120341555267, array([1]), (10, 129, 270, 283)), (0.63005745318879225, array([1]), (230, 242, 405, 352)), (0.5472707347607888, array([0]), (466, 177, 491, 205)), (0.60927910616268677, array([0]), (0, 76, 11, 117)), (0.68507625469249578, array([1]), (70, 126, 113, 139)), (0.5, array([0]), (0, 56, 24, 72)), (0.52461487328876655, array([0]), (0, 54, 25, 81)), (0.60650127145325361, array([1]), (33, 260, 149, 294)), (0.65746507401132082, array([1]), (15, 128, 83, 190)), (0.51566241267907442, array([0]), (405, 226, 499, 352)), (0.58187223386755071, array([0]), (36, 128, 73, 144)), (0.82654935607541902, array([0]), (0, 267, 50, 352)), (0.52700454358881998, array([0]), (40, 0, 54, 20)), (0.64018511141069134, array([0]), (0, 54, 41, 81)), (0.51903466506862339, array([0]), (444, 84, 493, 173)), (0.68261269608334119, array([1]), (10, 130, 269, 287)), (0.69129947505802669, array([0]), (426, 0, 443, 26)), (0.7839040688600204, array([1]), (17, 140, 94, 282)), (0.65583256151584945, array([1]), (23, 156, 40, 173)), (0.70558074454538811, array([1]), (247, 85, 348, 152)), (0.52461487328876655, array([0]), (0, 54, 25, 81)), (0.644788159872834, array([0]), (230, 45, 255, 57)), (0.70257269047276183, array([1]), (7, 238, 35, 262)), (0.5953603429911497, array([0]), (460, 147, 494, 225)), (0.5069366559862617, array([0]), (36, 301, 176, 352)), (0.56289009546905511, array([1]), (485, 0, 499, 24)), (0.65278238527837318, array([1]), (31, 202, 267, 306)), (0.71818795251215339, array([1]), (18, 127, 144, 194)), (0.6191578066118506, array([0]), (0, 76, 10, 110)), (0.52381712225840704, array([0]), (191, 158, 235, 198)), (0.60928074231603779, array([0]), (0, 163, 17, 200)), (0.56353834161861316, array([0]), (0, 133, 23, 147)), (0.5392467194200502, array([0]), (4, 107, 27, 128)), (0.58574332756712566, array([1]), (44, 146, 269, 277)), (0.64981257424607963, array([0]), (0, 111, 19, 128)), (0.5278990366748807, array([0]), (105, 149, 117, 174)), (0.6676696098062338, array([0]), (0, 53, 95, 104)), (0.69809369719481495, array([0]), (108, 62, 117, 120)), (0.57621220869732104, array([1]), (0, 96, 11, 117)), (0.58469834940423693, array([0]), (63, 0, 95, 54)), (0.83138770045152532, array([1]), (279, 212, 308, 234)), (0.56751496621493658, array([1]), (0, 33, 137, 200)), (0.64221337831897085, array([1]), (107, 227, 267, 288)), (0.78942042956019254, array([1]), (106, 273, 154, 288)), (0.66510348806243413, array([1]), (92, 197, 107, 242)), (0.66979411260861244, array([0]), (39, 0, 65, 28)), (0.55353519927623129, array([0]), (15, 129, 73, 194)), (0.6676696098062338, array([0]), (0, 53, 95, 104)), (0.5982202796928725, array([1]), (269, 142, 318, 187)), (0.81651385212029826, array([0]), (0, 199, 50, 352)), (0.58920009779012461, array([0]), (235, 172, 269, 192)), (0.5959427959031629, array([0]), (9, 64, 42, 91)), (0.56353834161861316, array([0]), (0, 133, 23, 147)), (0.55534270637465244, array([0]), (406, 0, 455, 32)), (0.65587919147353779, array([0]), (19, 312, 36, 352)), (0.53513266951294192, array([0]), (34, 276, 63, 299)), (0.69175334414989453, array([1]), (31, 256, 151, 291)), (0.60649395796235883, array([ ...
# [(0.53888367559889372, array([0]), (25, 297, 86, 334)), (0.65944462046113872, array([1]), (0, 275, 83, 334)), (0.83343030917763827, array([0]), (0, 152, 44, 230)), (0.6984066217940742, array([1]), (137, 196, 157, 243)), (0.68393470633998421, array([0]), (32, 231, 44, 252)), (0.54085923497949584, array([0]), (48, 189, 79, 242)), (0.65853277039869274, array([1]), (185, 88, 202, 105)), (0.64050107130929079, array([0]), (0, 231, 45, 257)), (0.89996356021055834, array([1]), (109, 255, 180, 271)), (0.5, array([0]), (248, 0, 399, 81)), (0.77684996996076694, array([0]), (0, 122, 42, 154)), (0.77265331365889811, array([0]), (0, 152, 43, 230)), (0.64735517633285566, array([1]), (0, 259, 43, 271)), (0.70474394683713659, array([1]), (0, 148, 42, 153)), (0.60421914131565013, array([1]), (45, 187, 54, 275)), (0.61640813879311385, array([1]), (0, 0, 72, 230)), (0.72195469562152392, array([1]), (243, 233, 298, 237)), (0.64735517633285566, array([1]), (0, 259, 43, 271)), (0.70896683105792535, array([1]), (107, 278, 122, 304)), (0.69060365044767769, array([0]), (0, 232, 35, 257)), (0.58999809473773557, array([1]), (85, 143, 115, 222)), (0.70474394683713659, array([1]), (0, 148, 42, 153)), (0.52767346516935554, array([0]), (309, 263, 466, 334)), (0.75505580258665017, array([1]), (0, 270, 44, 273)), (0.77265331365889811, array([0]), (0, 152, 43, 230)), (0.64292914136357882, array([0]), (0, 252, 77, 298)), (0.70474394683713659, array([1]), (0, 148, 42, 153)), (0.70612551771442533, array([1]), (256, 135, 275, 163)), (0.64805376424233863, array([1]), (0, 264, 43, 271)), (0.68635773233528785, array([1]), (0, 274, 22, 281)), (0.68140076640820335, array([1]), (69, 0, 163, 227)), (0.70474394683713659, array([1]), (0, 148, 42, 153)), (0.83343030917763827, array([0]), (0, 152, 44, 230)), (0.89207871114542758, array([1]), (218, 254, 348, 278)), (0.68140076640820335, array([1]), (69, 0, 163, 227)), (0.89207871114542758, array([1]), (218, 254, 348, 278)), (0.69434965555650952, array([1]), (0, 280, 82, 334)), (0.68635773233528785, array([1]), (0, 274, 22, 281)), (0.68263175129124387, array([0]), (0, 233, 44, 273)), (0.73011713238212939, array([1]), (105, 258, 223, 260)), (0.67129649406171676, array([1]), (138, 55, 173, 108)), (0.59153329259938814, array([1]), (0, 0, 73, 230)), (0.56349331760528332, array([0]), (159, 17, 176, 33)), (0.73761440562051239, array([0]), (73, 147, 80, 216)), (0.62073339392606441, array([1]), (85, 99, 100, 138)), (0.61102059389973351, array([1]), (83, 99, 146, 245)), (0.79654523999067395, array([0]), (55, 242, 89, 260)), (0.64508076108993206, array([1]), (148, 272, 165, 283)), (0.52767346516935554, array([0]), (309, 263, 466, 334)), (0.63011025270102772, array([1]), (55, 242, 80, 248)), (0.52931858305614965, array([0]), (154, 110, 173, 130)), (0.6031893314978789, array([1]), (271, 302, 291, 315)), (0.67620713720808201, array([1]), (107, 278, 121, 304)), (0.52767346516935554, array([0]), (309, 263, 466, 334)), (0.61640813879311385, array([1]), (0, 0, 72, 230)), (0.53857508279228095, array([0]), (48, 147, 81, 221)), (0.73853436904640068, array([1]), (186, 64, 304, 129)), (0.52492748435965064, array([0]), (173, 5, 189, 97)), (0.51824423430867383, array([0]), (0, 122, 44, 230)), (0.52331500887228732, array([0]), (0, 252, 45, 259)), (0.68936344060815002, array([1]), (0, 226, 44, 233)), (0.59153329259938814, array([1]), (0, 0, 73, 230)), (0.74060575253709326, array([1]), (0, 259, 43, 268)), (0.64008762626944793, array([0]), (480, 305, 499, 334)), (0.54864983409884405, array([0]), (55, 132, 82, 196)), (0.68060682437806252, array([1]), (162, 155, 180, 181)), (0.59636322890030369, array([1]), (0, 274, 77, 298)), (0.54300735150000101, array([0]), (150, 58, 235, 115)), (0.5, array([0]), (0, 207, 44, 241)), (0.76379505305506445, array([1]), (370, 87, 408, 109)), (0.61374403457177207, array([1]), (0, 272, 78, 298)), (0.54113743098496536, array([0]), (0, 233, 43, 258)), (0.57474223259062018, array([0]), (0, 232, 43, 258)), (0.51824423430867383, ar ...
# [(0.6680093020053659, array([1]), (0, 355, 32, 377)), (0.63894500543415322, array([1]), (0, 324, 20, 362)), (0.67971056586437117, array([1]), (11, 0, 110, 29)), (0.54227019232426954, array([0]), (0, 407, 40, 452)), (0.5, array([0]), (0, 25, 31, 156)), (0.53715131553840301, array([0]), (161, 337, 211, 383)), (0.5, array([0]), (91, 461, 159, 499)), (0.55035826550503608, array([0]), (0, 157, 33, 174)), (0.55029298858691189, array([0]), (213, 205, 310, 499)), (0.69722811903575688, array([1]), (0, 366, 79, 499)), (0.58874319459263036, array([0]), (0, 188, 42, 233)), (0.54335048969760957, array([0]), (0, 158, 33, 174)), (0.6923388305673116, array([1]), (81, 56, 131, 61)), (0.5, array([0]), (292, 205, 310, 215)), (0.78989043258634928, array([0]), (0, 139, 39, 192)), (0.63593132527140517, array([1]), (0, 466, 65, 499)), (0.65122152948247614, array([0]), (161, 254, 196, 269)), (0.58177866578825432, array([1]), (0, 43, 32, 156)), (0.50653933716039634, array([0]), (0, 26, 143, 195)), (0.88129025342305467, array([1]), (0, 0, 142, 36)), (0.52321736904038463, array([0]), (0, 267, 60, 347)), (0.66657283139128753, array([1]), (219, 390, 295, 499)), (0.5274227819893812, array([0]), (0, 159, 21, 173)), (0.56457699340537537, array([0]), (0, 266, 34, 287)), (0.63752392236140965, array([0]), (0, 165, 37, 192)), (0.65358566362159942, array([0]), (99, 353, 190, 392)), (0.57413795026899184, array([1]), (0, 407, 36, 437)), (0.58736423196503529, array([1]), (0, 155, 31, 173)), (0.64052655385384405, array([1]), (9, 22, 20, 74)), (0.60376130011808182, array([0]), (0, 14, 13, 32)), (0.5986071041194686, array([0]), (0, 179, 54, 279)), (0.55618794960590079, array([0]), (0, 212, 19, 230)), (0.719340032580573, array([1]), (199, 478, 226, 490)), (0.5986071041194686, array([0]), (0, 179, 54, 279)), (0.71309469822660054, array([1]), (41, 425, 66, 447)), (0.62263606757683199, array([1]), (37, 226, 47, 242)), (0.53104745969278111, array([0]), (0, 25, 12, 79)), (0.54045589983051068, array([0]), (0, 14, 13, 31)), (0.54710820045160713, array([0]), (0, 371, 28, 406)), (0.59906490036632798, array([1]), (91, 120, 136, 159)), (0.56306102157127258, array([0]), (0, 179, 54, 257)), (0.6377092456812582, array([1]), (189, 321, 200, 348)), (0.56153641299804369, array([0]), (0, 262, 56, 317)), (0.75981745510186327, array([1]), (20, 7, 77, 25)), (0.63542841328546262, array([0]), (39, 348, 70, 372)), (0.5, array([0]), (85, 397, 95, 425)), (0.55475170048914579, array([0]), (0, 53, 31, 158)), (0.58770344162815535, array([0]), (370, 231, 374, 275)), (0.52321736904038463, array([0]), (0, 267, 60, 347)), (0.76975849829888998, array([1]), (0, 231, 34, 237)), (0.67687086798022245, array([1]), (87, 92, 104, 116)), (0.54611229595720256, array([0]), (83, 206, 97, 228)), (0.62857910025157382, array([0]), (0, 154, 37, 192)), (0.71398653366875509, array([0]), (0, 339, 12, 362)), (0.63649112210137293, array([1]), (69, 88, 119, 125)), (0.52321736904038463, array([0]), (0, 267, 60, 347)), (0.83152158972720835, array([1]), (56, 312, 170, 361)), (0.56016021971343533, array([0]), (18, 67, 25, 94)), (0.68000362623789601, array([1]), (0, 202, 112, 260)), (0.63371569839994035, array([0]), (0, 174, 45, 223)), (0.58749961198037071, array([0]), (0, 236, 38, 279)), (0.5, array([0]), (0, 43, 32, 158)), (0.61416684531254517, array([1]), (25, 419, 49, 449)), (0.75249588944397139, array([0]), (0, 236, 45, 288)), (0.75046807164545781, array([1]), (0, 20, 22, 89)), (0.5, array([0]), (23, 95, 31, 134)), (0.6915166638695599, array([0]), (41, 385, 78, 446)), (0.51718843143599247, array([0]), (91, 120, 113, 150)), (0.59104276367133302, array([0]), (289, 0, 315, 201)), (0.82769160725025115, array([1]), (164, 462, 220, 499)), (0.50840110734146837, array([0]), (0, 169, 37, 192)), (0.69196173108667225, array([0]), (0, 143, 40, 192)), (0.77369081681797758, array([1]), (85, 126, 114, 150)), (0.66657283139128753, array([1]), (219, 390, 295, 499)), (0.57061086733672306, array([0]), (0, 155, 33, 175)), (0.6408455024579639,  ...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-38-bc13e8fe1bce> in <module>()
#       6     probs,labels = list(),list()
#       7     for regn in regions:
# ----> 8         fd = extract(img,regn)
#       9         probs.append(max(clf.predict_proba([fd])[0]))
#      10         labels.append(clf.predict([fd]))
#
# <ipython-input-6-174e86ae57ee> in extract(image, box)
#      10     #print image.shape
#      11     #print len(image)
# ---> 12     image = resize(image)
#      13     #print image.shape
#      14     #image = color.rgb2gray(img)
#
# <ipython-input-6-174e86ae57ee> in resize(image)
#      22         image = cv2.resize(image,(128,64))
#      23     elif float(image.shape[1])/image.shape[0] <= 0.5:
# ---> 24         image = cv2.resize(image,(64,128))
#      25     else:
#      26         image = cv2.resize(image,(128,128))
#
# error: /home/arjun/opencv-2.4.13/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize

# %%
from skimage.feature import hog
extract(imgs[0],[10,10,100,300])

# %%
max?
